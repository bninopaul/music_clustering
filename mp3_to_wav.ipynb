# %%
from scipy.io import wavfile
from IPython.core.display import HTML
# %matplotlib inline
def wavPlayer(filepath):
    """ will display html 5 player for compatible browser

    Parameters :
    ------------
    filepath : relative filepath with respect to the notebook directory ( where the .ipynb are not cwd)
               of the file to play

    The browser need to know how to play wav through html5.

    there is no autoplay to prevent file playing when the browser opens
    """
    
    src = """
    <head>
    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
    <title>Simple Test</title>
    </head>
    
    <body>
    <audio controls="controls" style="width:600px" >
      <source src="files/%s" type="audio/wav" />
      Your browser does not support the audio element.
    </audio>
    </body>
    """%(filepath)

    display(HTML(src))
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rate,sample = wavfile.read('output.wav')#stereo file

# %%
plt.figure(figsize=(20,5))
plt.plot(sample[:, 0][:len(sample)/2])

# %%
plt.figure(figsize=(20,5))
plt.plot(sample[:, 1][:len(sample)/2])

# %%
ave_sample = np.mean(sample.astype(float), axis = 1)
plt.figure(figsize=(20,5))
plt.plot(ave_sample[:len(sample)/2])

# %%
wavfile.write('output_mono.wav', rate = rate, data = ave_sample.astype(np.int16))

# %%
wavPlayer("output_mono.wav")
# Out:
#     <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <title>Simple Test</title>
#     </head>
#
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source src="files/output_mono.wav" type="audio/wav" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>

# %%
a = np.fft.fft(ave_sample)

# %%
plt.figure(figsize = (20,5))
plt.plot(np.real(a))
plt.plot(np.imag(a))
